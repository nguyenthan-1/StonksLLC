# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import yfinance as yf

# %%
#write a function 
#function grab, ticker name the users input, startdate, enddate, adjusted close price, visualize in a line plot 
#ticker= input(str("Please input the ticker name:"))
def five_years_stock_performance(ticker):
    
    start_date = '2018-01-01'
    end_date = '2022-01-01'
   
    stockinfo = yf.download(ticker, start_date, end_date)
    
    stockinfo['Adj Close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
    plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)
    plt.ylabel('Price', fontsize=14)
    plt.xlabel('Year', fontsize=14)

# Plot the grid lines
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
    plt.show()

# %%
five_years_stock_performance('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#write function to compare the stock with S&P 500 
#get s&p data 
start_date = '2018-01-01'
end_date = '2022-01-01'
ticker = '^GSPC'
stockinfo = yf.download(ticker, start_date, end_date,interval='1mo')
stockinfo.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-01  2683.729980  2872.870117  2682.360107  2823.810059  2823.810059
# 2018-02-01  2816.449951  2835.959961  2532.689941  2713.830078  2713.830078
# 2018-03-01  2715.219971  2801.899902  2585.889893  2640.870117  2640.870117
# 2018-04-01  2633.449951  2717.489990  2553.800049  2648.050049  2648.050049
# 2018-05-01  2642.959961  2742.239990  2594.620117  2705.270020  2705.270020
#
#                  Volume
# Date
# 2018-01-01  77318690000
# 2018-02-01  79933970000
# 2018-03-01  76803890000
# 2018-04-01  70194700000
# 2018-05-01  76011820000

# %%
ticker1 = 'AAPL'
stockinfo1 = yf.download(ticker1, start_date, end_date)
stockinfo1.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-02  42.540001  43.075001  42.314999  43.064999  40.950500  102223600
# 2018-01-03  43.132500  43.637501  42.990002  43.057499  40.943363  118071600
# 2018-01-04  43.134998  43.367500  43.020000  43.257500  41.133545   89738400
# 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.601868   94640000
# 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.447342   82271200

# %%
stockinfo1.iloc[-1]
# Out:
# Open         1.780900e+02
# High         1.792300e+02
# Low          1.772600e+02
# Close        1.775700e+02
# Adj Close    1.765454e+02
# Volume       6.406230e+07
# Name: 2021-12-31 00:00:00, dtype: float64

# %%
stockinfo1['aapl_return']=(stockinfo1['Adj Close']/ stockinfo1['Adj Close'].shift(1)) -1
stockinfo1['aapl_return'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#calculate the return of S&P500 and the stock you want to plot 
stockinfo['snp500_return']=(stockinfo['Adj Close']/ stockinfo['Adj Close'].shift(1)) -1
stockinfo['snp500_return'].plot()
plt.title("return of %s" % ticker, fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()
#show cl

# %%
#plt.plot(snp500_return,aapl_return)
plt.figure(figsize=(10,7))
plt.plot(stockinfo['snp500_return'], color='red')
plt.plot(stockinfo1['aapl_return'], color='green')
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()

# %%
def returnof_SnP500_and_stock(ticker): 
    start_date = '2018-01-01'
    end_date = '2022-01-01'

    stockinfo1 = yf.download(ticker, start_date, end_date,interval='1mo')
    stockinfo1['ticker_return']=(stockinfo1['Adj Close']/ stockinfo1['Adj Close'].shift(1)) -1
    
    plt.figure(figsize=(10,7))
    plt.plot(stockinfo['snp500_return'], color='red')
    plt.plot(stockinfo1['ticker_return'], color='green')
    plt.title("comparison of %s" % ticker, fontsize=16)
    plt.ylabel('Percentage', fontsize=14)
    plt.xlabel('Year', fontsize=14)

# Plot the grid lines
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
    plt.ylim(-0.5, 1)
   

# Show the plot
    plt.show()
    
    
#set ylimit?

# %%
returnof_SnP500_and_stock('AMZN')
# Out:
# [*********************100%***********************]  1 of 1 completed
